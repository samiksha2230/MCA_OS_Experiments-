# %%
# Deadlock Prevention using Resource Ordering

# List of resources
resources = ["R1", "R2", "R3"]

# Sort resources to enforce a consistent acquisition order
resources.sort()

# Simulate acquiring resources in sorted order
print("Apply Resource Ordering:")
for resource in resources:
    print("Acquire", resource)
# Out:
# Apply Resource Ordering:
# Acquire R1
# Acquire R2
# Acquire R3

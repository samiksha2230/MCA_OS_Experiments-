# %%
pages = [1,3,0,3,5,6,3]
capacity = 3
memory = []
Faults = 0
for page in pages:
    if page not in memory:
        Faults+=1
        if len(memory) == capacity:
            memory.pop(0)
        memory.append(page)
        print(f"Page {page} -> Memory: {memory}")
        print("Total page faults(FIFO):",Faults)

        memory = []
        faults = 0
        for page in pages:
            if page not in memory:
                faults += 1
                if len(memory) == capacity:
                    memory.pop(0)
                memory.append(page)
            else:
                memory.remove(page)
                memory.append(page)
            print(f"Page {page} -> Memory: {memory}")
            print("Total page faults(LRU):", faults)
# Out:
# Page 1 -> Memory: [1]
# Total page faults(FIFO): 1
# Page 1 -> Memory: [1]
# Total page faults(LRU): 1
# Page 3 -> Memory: [1, 3]
# Total page faults(LRU): 2
# Page 0 -> Memory: [1, 3, 0]
# Total page faults(LRU): 3
# Page 3 -> Memory: [1, 0, 3]
# Total page faults(LRU): 3
# Page 5 -> Memory: [0, 3, 5]
# Total page faults(LRU): 4
# Page 6 -> Memory: [3, 5, 6]
# Total page faults(LRU): 5
# Page 3 -> Memory: [5, 6, 3]
# Total page faults(LRU): 5
# Page 0 -> Memory: [6, 3, 0]
# Total page faults(FIFO): 2
# Page 1 -> Memory: [1]
# Total page faults(LRU): 1
# Page 3 -> Memory: [1, 3]
# Total page faults(LRU): 2
# Page 0 -> Memory: [1, 3, 0]
# Total page faults(LRU): 3
# Page 3 -> Memory: [1, 0, 3]
# Total page faults(LRU): 3
# Page 5 -> Memory: [0, 3, 5]
# Total page faults(LRU): 4
# Page 6 -> Memory: [3, 5, 6]
# Total page faults(LRU): 5
# Page 3 -> Memory: [5, 6, 3]
# Total page faults(LRU): 5
